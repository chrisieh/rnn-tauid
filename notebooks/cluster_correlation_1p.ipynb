# %%
from os import path

import numpy as np
import h5py
from tqdm import tqdm

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from rnn_tauid.common.mpl_setup import mpl_setup
mpl_setup()

from rnn_tauid.evaluation.misc import pearsonr

# %%
# Sample paths
features_fname = "/lustre/user/cdeutsch/rnn-feature-samples-v5/cluster/cluster_features_1p.h5"

# Plot output prefix
plot_prefix = "/lustre/user/cdeutsch/rnn-feature-samples-v5/cluster/cluster_features_1p_plots/"

# %%
features = h5py.File(features_fname, "r")

# %%
label = features["label"][...]
weight = features["weight"][...]

# %%
def corr(arr):
    L = []
    for i in range(6):
        a = arr[:, i]
        mask = ~np.isnan(a)
        r = pearsonr(a[mask], label[mask], weights=weight[mask])
        L.append(r)
    
    return np.array(L)

# %%
x = np.arange(1, 7)

# %%
c_et = corr(features["data/TauClusters.et_log"])
fig, ax = plt.subplots()
ax.plot(x, c_et, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.7, 0.7)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)
# Out:
# /lustre/user/cdeutsch/miniconda2/envs/ML/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c_psfrac = corr(features["data/TauClusters.psfrac"])
fig, ax = plt.subplots()
ax.plot(x, c_psfrac, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.2, 0.2)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_em1frac = corr(features["data/TauClusters.em1frac"])
fig, ax = plt.subplots()
ax.plot(x, c_em1frac, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.1, 0.1)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_em2frac = corr(features["data/TauClusters.em2frac"])
fig, ax = plt.subplots()
ax.plot(x, c_em2frac, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.2, 0.2)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_em3frac = corr(features["data/TauClusters.em3frac"])
fig, ax = plt.subplots()
ax.plot(x, c_em3frac, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.1, 0.1)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_dR = corr(features["data/TauClusters.dRJetSeedAxis"])
fig, ax = plt.subplots()
ax.plot(x, c_dR, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.5, 0.5)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_emProb = corr(features["data/TauClusters.EM_PROBABILITY"])
fig, ax = plt.subplots()
ax.plot(x, c_emProb, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.2, 0.2)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_r2 = corr(features["data/TauClusters.SECOND_R_log"])
fig, ax = plt.subplots()
ax.plot(x, c_r2, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.3, 0.3)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_lambda2 = corr(features["data/TauClusters.SECOND_LAMBDA_log"])
fig, ax = plt.subplots()
ax.plot(x, c_lambda2, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.2, 0.2)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_rho = corr(features["data/TauClusters.FIRST_ENG_DENS_log"])
fig, ax = plt.subplots()
ax.plot(x, c_rho, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.2, 0.2)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_lambdacenter = corr(features["data/TauClusters.CENTER_LAMBDA_log"])
fig, ax = plt.subplots()
ax.plot(x, c_lambdacenter, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.15, 0.15)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
c_engfracmax = corr(features["data/TauClusters.ENG_FRAC_MAX"])
fig, ax = plt.subplots()
ax.plot(x, c_engfracmax, "o")
ax.axhline(0.0, linestyle=":", linewidth=1.0, color="grey", zorder=0)
ax.set_xlim(0.5, 6.5)
ax.set_xticks(x)
ax.set_ylim(-0.3, 0.3)
ax.set_xlabel("Number of track in sequence", ha="right", x=1.0)
ax.set_ylabel(r"$\rho(, y_\mathrm{true})$", ha="right", y=1.0)

# %%
vn = ["et_log", "psfrac", "em1frac", "em2frac", "em3frac",
      "dRJetSeedAxis", "EM_PROBABILITY", "SECOND_R_log",
      "SECOND_LAMBDA_log", "FIRST_ENG_DENS_log",
      "CENTER_LAMBDA_log", "ENG_FRAC_MAX"]

#names = [r"$\log_{10}\left( p_\mathrm{T} \right)$",
#         r"$p_\mathrm{T}^\mathrm{asym.}$",
#         r"$\log_{10}\left( |d_0| + \varepsilon \right)$",
#         r"$\log_{10}\left( |z_0 \sin\theta| + \varepsilon \right)$",
#         r"$\Delta R_\mathrm{JetSeedAxis}$",
#         r"eProbabilityHT",
#         r"nInnermostPixelHits",
#         r"nPixelHits",
#         r"nSiHits"]

sd = dict()
for i, v in enumerate(vn):
    sd[i] = features["data/TauClusters.{}".format(v)][:, 0]

mat = np.eye(12)

# %%
from itertools import product

# %%
evals = [(i, j) for i,j in product(range(12), range(12)) if i > j]

# %%
for i, j in evals:
    mask = ~np.isnan(sd[i])
    mat[i,j] = pearsonr(sd[i][mask], sd[j][mask], weights=weight[mask])

# %%
mask = ~np.tri(12, dtype=np.bool)
ma_mat = np.ma.array(mat, mask=mask)

fig, ax = plt.subplots(figsize=(9,9))
im = ax.imshow(ma_mat, cmap="bwr", vmin=-1, vmax=1)

ax.set_xticks(np.arange(12))
ax.set_xticklabels(vn, rotation="vertical")

ax.set_yticks(np.arange(12))
ax.set_yticklabels(vn)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.minorticks_off()
ax.tick_params(which="both", top="off", bottom="off", right="off", left="off")
#ax.yaxis.set_ticks_position("left")
#ax.xaxis.set_ticks_position("bottom")

for i,j in product(range(12), range(12)):
    if i >= j:
        ax.text(j, i, "${:.2f}$".format(np.round(mat[i,j], decimals=2)+0), ha="center", va="center")

#fig.tight_layout()
#fig.savefig(path.join(plot_prefix, "corrmat.pdf"))

# %%
features.close()
